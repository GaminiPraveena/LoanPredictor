# %% [markdown]
# Loan prediction using DECISION CLASSIFIER

# %%
#Project
#3
#DECISION CLASSIFIER
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz,plot_tree

# %%
df=pd.read_csv("/content/Loan.csv")
df
# Out:
#            LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0      I38PQUQS96   56   85994       50587          520              80
# 1      HPSK72WA7R   69   50432      124440          458              15
# 2      C1OZ6DPJ8Y   46   84208      129188          451              26
# 3      V2KKSFM3UN   32   31713       44799          743               0
# 4      EY08JDHTZP   60   20437        9139          633               8
# ...           ...  ...     ...         ...          ...             ...
# 21556  B4SHWZV6M4   55  119214       59748          801             107
# 21557  O8HPEMGSVP   39   24748      244203          705              95
# 21558  TZGD4C4FL1   66  129596       61466          644              89
# 21559  JNF4IOYSXL   65   46886       45898          552              78
# 21560  TGWBVKCR0S   64  143515      215662          331              59
#
#        NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# 0                   4         15.23        36      0.44   Bachelor's
# 1                   1          4.81        60      0.68     Master's
# 2                   3         21.17        24      0.31     Master's
# 3                   3          7.07        24      0.23  High School
# 4                   4          6.51        48      0.73   Bachelor's
# ...               ...           ...       ...       ...          ...
# 21556               2         15.09        12      0.11  High School
# 21557               2         20.54        60      0.69   Bachelor's
# 21558               4          6.71        12      0.17          PhD
# 21559               4         15.83        60      0.60  High School
# 21560               2         19.91        48      0.46  High School
#
#       EmploymentType MaritalStatus HasMortgage HasDependents LoanPurpose  \
# 0          Full-time      Divorced         Yes           Yes       Other
# 1          Full-time       Married          No            No       Other
# 2         Unemployed      Divorced         Yes           Yes        Auto
# 3          Full-time       Married          No            No    Business
# 4         Unemployed      Divorced          No           Yes        Auto
# ...              ...           ...         ...           ...         ...
# 21556      Full-time       Married          No            No        Auto
# 21557      Part-time        Single         Yes            No       Other
# 21558  Self-employed       Married          No           Yes    Business
# 21559      Part-time       Married         Yes            No   Education
# 21560     Unemployed        Single          No           Yes           E
#
#       HasCoSigner  Default
# 0             Yes      0.0
# 1             Yes      0.0
# 2              No      1.0
# 3              No      0.0
# 4              No      0.0
# ...           ...      ...
# 21556          No      0.0
# 21557          No      1.0
# 21558          No      0.0
# 21559          No      0.0
# 21560         NaN      NaN
#
# [21561 rows x 18 columns]

# %%
feature_cols=['Income','LoanAmount','MonthsEmployed','DTIRatio']
features=df.loc[0:99,feature_cols]
Target=df.loc[0:99,'Default']  #target variable
df
# Out:
#            LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0      I38PQUQS96   56   85994       50587          520              80
# 1      HPSK72WA7R   69   50432      124440          458              15
# 2      C1OZ6DPJ8Y   46   84208      129188          451              26
# 3      V2KKSFM3UN   32   31713       44799          743               0
# 4      EY08JDHTZP   60   20437        9139          633               8
# ...           ...  ...     ...         ...          ...             ...
# 21556  B4SHWZV6M4   55  119214       59748          801             107
# 21557  O8HPEMGSVP   39   24748      244203          705              95
# 21558  TZGD4C4FL1   66  129596       61466          644              89
# 21559  JNF4IOYSXL   65   46886       45898          552              78
# 21560  TGWBVKCR0S   64  143515      215662          331              59
#
#        NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# 0                   4         15.23        36      0.44   Bachelor's
# 1                   1          4.81        60      0.68     Master's
# 2                   3         21.17        24      0.31     Master's
# 3                   3          7.07        24      0.23  High School
# 4                   4          6.51        48      0.73   Bachelor's
# ...               ...           ...       ...       ...          ...
# 21556               2         15.09        12      0.11  High School
# 21557               2         20.54        60      0.69   Bachelor's
# 21558               4          6.71        12      0.17          PhD
# 21559               4         15.83        60      0.60  High School
# 21560               2         19.91        48      0.46  High School
#
#       EmploymentType MaritalStatus HasMortgage HasDependents LoanPurpose  \
# 0          Full-time      Divorced         Yes           Yes       Other
# 1          Full-time       Married          No            No       Other
# 2         Unemployed      Divorced         Yes           Yes        Auto
# 3          Full-time       Married          No            No    Business
# 4         Unemployed      Divorced          No           Yes        Auto
# ...              ...           ...         ...           ...         ...
# 21556      Full-time       Married          No            No        Auto
# 21557      Part-time        Single         Yes            No       Other
# 21558  Self-employed       Married          No           Yes    Business
# 21559      Part-time       Married         Yes            No   Education
# 21560     Unemployed        Single          No           Yes           E
#
#       HasCoSigner  Default
# 0             Yes      0.0
# 1             Yes      0.0
# 2              No      1.0
# 3              No      0.0
# 4              No      0.0
# ...           ...      ...
# 21556          No      0.0
# 21557          No      1.0
# 21558          No      0.0
# 21559          No      0.0
# 21560         NaN      NaN
#
# [21561 rows x 18 columns]

# %%
#create the model
from sklearn.linear_model import LinearRegression
model=DecisionTreeClassifier()
#train the model
model.fit(features,Target)
# Out:
# DecisionTreeClassifier()

# %%
pre=model.predict([[85994,50587,80.0,0.44]])
pre1=model.predict([[84208,129188,26,0.31]])
print(pre)
print(pre1)
# Out:
# [0.]
# [1.]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
#'Income','LoanAmount','MonthsEmployed','DTIRatio'
p1=int(input("enter your income:" ))
p2=int(input("enter your LoanAmount:"))
p3=float(input("enter MonthsEmployed :"))
p4=float(input("enter DITRatio :"))
pre=model.predict([[p1,p2,p3,p4]])
if pre==1:
  print("Congrats! you will get loan")
else:
  print("Sorry you dont get loan")
# Out:
# enter your income:84208
# enter your LoanAmount:129188
# enter MonthsEmployed :26
# enter DITRatio :0.31
# Congrats! you will get loan
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
plot_tree(model)
# Out:
# [Text(0.5330882352941176, 0.9583333333333334, 'x[2] <= 115.5\ngini = 0.241\nsamples = 100\nvalue = [86, 14]'),
#  Text(0.41544117647058826, 0.875, 'x[1] <= 76434.5\ngini = 0.219\nsamples = 96\nvalue = [84, 12]'),
#  Text(0.35661764705882354, 0.7916666666666666, 'gini = 0.0\nsamples = 26\nvalue = [26, 0]'),
#  Text(0.4742647058823529, 0.7916666666666666, 'x[3] <= 0.79\ngini = 0.284\nsamples = 70\nvalue = [58, 12]'),
#  Text(0.2867647058823529, 0.7083333333333334, 'x[3] <= 0.125\ngini = 0.242\nsamples = 64\nvalue = [55, 9]'),
#  Text(0.22794117647058823, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.34558823529411764, 0.625, 'x[0] <= 25008.0\ngini = 0.222\nsamples = 63\nvalue = [55, 8]'),
#  Text(0.14705882352941177, 0.5416666666666666, 'x[1] <= 166095.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.08823529411764706, 0.4583333333333333, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.20588235294117646, 0.4583333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5441176470588235, 0.5416666666666666, 'x[3] <= 0.315\ngini = 0.185\nsamples = 58\nvalue = [52, 6]'),
#  Text(0.3235294117647059, 0.4583333333333333, 'x[3] <= 0.28\ngini = 0.346\nsamples = 18\nvalue = [14, 4]'),
#  Text(0.2647058823529412, 0.375, 'x[0] <= 45583.0\ngini = 0.291\nsamples = 17\nvalue = [14, 3]'),
#  Text(0.11764705882352941, 0.2916666666666667, 'x[1] <= 125242.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.058823529411764705, 0.20833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.17647058823529413, 0.20833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4117647058823529, 0.2916666666666667, 'x[2] <= 33.5\ngini = 0.231\nsamples = 15\nvalue = [13, 2]'),
#  Text(0.29411764705882354, 0.20833333333333334, 'x[2] <= 27.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.23529411764705882, 0.125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.35294117647058826, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5294117647058824, 0.20833333333333334, 'x[1] <= 143540.5\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.47058823529411764, 0.125, 'x[1] <= 122796.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.4117647058823529, 0.041666666666666664, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.5294117647058824, 0.041666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5882352941176471, 0.125, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.38235294117647056, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7647058823529411, 0.4583333333333333, 'x[3] <= 0.745\ngini = 0.095\nsamples = 40\nvalue = [38, 2]'),
#  Text(0.6470588235294118, 0.375, 'x[0] <= 135360.5\ngini = 0.054\nsamples = 36\nvalue = [35, 1]'),
#  Text(0.5882352941176471, 0.2916666666666667, 'gini = 0.0\nsamples = 30\nvalue = [30, 0]'),
#  Text(0.7058823529411765, 0.2916666666666667, 'x[3] <= 0.565\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.6470588235294118, 0.20833333333333334, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.7647058823529411, 0.20833333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8823529411764706, 0.375, 'x[2] <= 55.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.8235294117647058, 0.2916666666666667, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.9411764705882353, 0.2916666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6617647058823529, 0.7083333333333334, 'x[3] <= 0.835\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.6029411764705882, 0.625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7205882352941176, 0.625, 'x[2] <= 16.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.6617647058823529, 0.5416666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7794117647058824, 0.5416666666666666, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.6507352941176471, 0.875, 'x[1] <= 84060.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.5919117647058824, 0.7916666666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7095588235294118, 0.7916666666666666, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]')]

# %% [markdown]
# Loan prediction using RANDOM FOREST

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier

# %%
df1=pd.read_csv("/content/project_loan.csv")
df1
# Out:
#            LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0      I38PQUQS96   56   85994       50587          520              80
# 1      HPSK72WA7R   69   50432      124440          458              15
# 2      C1OZ6DPJ8Y   46   84208      129188          451              26
# 3      V2KKSFM3UN   32   31713       44799          743               0
# 4      EY08JDHTZP   60   20437        9139          633               8
# ...           ...  ...     ...         ...          ...             ...
# 42688  S9RP0KW5FC   49   78284      102644          647               6
# 42689  B4BS1LFD8T   26   68869       72616          505              72
# 42690  L3MAJRM39Q   39   84860      124150          779             114
# 42691  4MC9RUD9M1   27   93690       93023          601              54
# 42692  S644QEMWLQ   46  108072      226559          633              54
#
#        NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# 0                   4         15.23        36      0.44   Bachelor's
# 1                   1          4.81        60      0.68     Master's
# 2                   3         21.17        24      0.31     Master's
# 3                   3          7.07        24      0.23  High School
# 4                   4          6.51        48      0.73   Bachelor's
# ...               ...           ...       ...       ...          ...
# 42688               3         15.08        48      0.43  High School
# 42689               3         13.82        48      0.26  High School
# 42690               1         11.73        36      0.85  High School
# 42691               3         18.33        60      0.41          PhD
# 42692               2         11.39        24      0.48     Master's
#
#       EmploymentType MaritalStatus HasMortgage HasDependents LoanPurpose  \
# 0          Full-time      Divorced         Yes           Yes       Other
# 1          Full-time       Married          No            No       Other
# 2         Unemployed      Divorced         Yes           Yes        Auto
# 3          Full-time       Married          No            No    Business
# 4         Unemployed      Divorced          No           Yes        Auto
# ...              ...           ...         ...           ...         ...
# 42688  Self-employed      Divorced         Yes           Yes        Auto
# 42689  Self-employed        Single         Yes           Yes   Education
# 42690     Unemployed       Married         Yes            No    Business
# 42691     Unemployed      Divorced         Yes            No   Education
# 42692     Unemployed           NaN         NaN           NaN         NaN
#
#       HasCoSigner  Status
# 0             Yes     0.0
# 1             Yes     0.0
# 2              No     1.0
# 3              No     0.0
# 4              No     0.0
# ...           ...     ...
# 42688          No     0.0
# 42689         Yes     0.0
# 42690         Yes     0.0
# 42691          No     0.0
# 42692         NaN     NaN
#
# [42693 rows x 18 columns]

# %%
feature_cols1=['Income','LoanAmount','MonthsEmployed','DTIRatio']
features1=df1.loc[0:99,feature_cols1]    #features=df.loc[0:99,feature_cols]
Target=df1.loc[0:99,'Status']  #target variable

# %%
#create the model
#from sklearn.linear_model import LinearRegression
DT=RandomForestClassifier(n_estimators=10)
#train the model
DT.fit(features1,Target)
# Out:
# RandomForestClassifier(n_estimators=10)

# %%
pre2=DT.predict([[85994,50587,80.0,0.44]])
pre3=DT.predict([[84208,129188,26,0.31]])
print(pre2)
print(pre3)
# Out:
# [0.]
# [1.]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
#'Income','LoanAmount','MonthsEmployed','DTIRatio'
p1=int(input("enter your income:" ))
p2=int(input("enter your LoanAmount:"))
p3=float(input("enter MonthsEmployed :"))
p4=float(input("enter DITRatio :"))
pre=DT.predict([[p1,p2,p3,p4]])
if pre==1:
  print("Congrats! you will get loan")
else:
  print("Sorry you dont get loan")
# Out:
# enter your income:84208
# enter your LoanAmount:129188
# enter MonthsEmployed :26
# enter DITRatio :0.31
# Congrats! you will get loan
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
import os
output_dir="tree_visualizations"
os.makedirs(output_dir,exist_ok=True)

# %%
for i,tree in enumerate(DT.estimators_):
  tree_dot_file = os.path.join(output_dir,f"tree_{i}.dot")
  tree_png_file = os.path.join(output_dir,f"tree_{i}.png")

# %%
DT.estimators_  #model  name=DT
# Out:
# [DecisionTreeClassifier(max_features='sqrt', random_state=56689117),
#  DecisionTreeClassifier(max_features='sqrt', random_state=962054272),
#  DecisionTreeClassifier(max_features='sqrt', random_state=13767395),
#  DecisionTreeClassifier(max_features='sqrt', random_state=233956656),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1437284710),
#  DecisionTreeClassifier(max_features='sqrt', random_state=304252403),
#  DecisionTreeClassifier(max_features='sqrt', random_state=962225469),
#  DecisionTreeClassifier(max_features='sqrt', random_state=861195562),
#  DecisionTreeClassifier(max_features='sqrt', random_state=310255006),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1558681801)]

# %%
from sklearn.tree import export_graphviz
export_graphviz(tree, out_file=tree_dot_file, feature_names=['Income','LoanAmount','MonthsEmployed','DTIRatio'],
                    class_names=[str(cls) for cls in DT.classes_], filled=True, rounded=True)

# %%
command = f"dot -Tpng {tree_dot_file} -o {tree_png_file}"
os.system(command)
print(f"Tree {i} visualization saved to {tree_png_file}")
# Out:
# Tree 9 visualization saved to tree_visualizations/tree_9.png

# %%
#Profit prediction using LinearRegression
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
model=LinearRegression()
df=pd.read_csv("/content/project_loan.csv")
t=np.array([i for i in df["Income"]]).reshape(-1,1)
p=df["LoanAmount"]
model.fit(t,p)
n=int(input("Enter income:"))
status=(model.predict([[n]]))
#print(status)
if(status==1):
  print("yes")
else:
  print("no")
# Out:
# Enter income:84208
# no
